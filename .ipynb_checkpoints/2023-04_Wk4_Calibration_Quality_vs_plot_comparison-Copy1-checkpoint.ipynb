# %%
import os
wd= 'C:/Users/Phil/Documents/GitHub/hbv-globalinvcase'#set own working directory
os.chdir(wd)

import atomica as at
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import hbv_functions as hbv

# %%
# %matplotlib inline

# %%
regions = ['AFR', 'AMR', 'EMR', 'EUR', 'SEAR', 'WPR']
edf = hbv.error_table(regions)
# Out:
# Current region: AFR
# Elapsed time for running "default": 2.04s
# Current region: AMR
# Elapsed time for running "default": 2.07s
# Current region: EMR
# Elapsed time for running "default": 2.04s
# Current region: EUR
# Elapsed time for running "default": 2.03s
# Current region: SEAR
# Elapsed time for running "default": 2.02s
# Current region: WPR
# Elapsed time for running "default": 2.04s

# %%
edf
# Out:
#       chb_pop  cl_acu  cl_cir  cl_hcc
# AFR    0.2517  0.1349  0.0847  0.1731
# AMR    0.2972  0.2728  0.1721  0.2041
# EMR    0.3038  0.5231  0.2043  0.2167
# EUR    0.1721  0.3919  0.1634  0.0910
# SEAR   0.2581  0.1978  0.1101  0.1960
# WPR    0.3053  0.4285  0.1827  0.1599

# %%
hbv.determine_cal_quality(edf)
# Out:
# <style type="text/css">
# #T_02e05_row0_col0, #T_02e05_row0_col1, #T_02e05_row0_col2, #T_02e05_row0_col3, #T_02e05_row1_col0, #T_02e05_row1_col1, #T_02e05_row1_col2, #T_02e05_row1_col3, #T_02e05_row2_col0, #T_02e05_row2_col2, #T_02e05_row2_col3, #T_02e05_row3_col0, #T_02e05_row3_col1, #T_02e05_row3_col2, #T_02e05_row3_col3, #T_02e05_row4_col0, #T_02e05_row4_col1, #T_02e05_row4_col2, #T_02e05_row4_col3, #T_02e05_row5_col0, #T_02e05_row5_col2, #T_02e05_row5_col3 {
#   color: black;
#   background-color: mediumseagreen;
# }
# #T_02e05_row2_col1, #T_02e05_row5_col1 {
#   color: black;
#   background-color: gold;
# }
# </style>
# <table id="T_02e05_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >chb_pop</th>
#       <th class="col_heading level0 col1" >cl_acu</th>
#       <th class="col_heading level0 col2" >cl_cir</th>
#       <th class="col_heading level0 col3" >cl_hcc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02e05_level0_row0" class="row_heading level0 row0" >AFR</th>
#       <td id="T_02e05_row0_col0" class="data row0 col0" >0.251700</td>
#       <td id="T_02e05_row0_col1" class="data row0 col1" >0.134900</td>
#       <td id="T_02e05_row0_col2" class="data row0 col2" >0.084700</td>
#       <td id="T_02e05_row0_col3" class="data row0 col3" >0.173100</td>
#     </tr>
#     <tr>
#       <th id="T_02e05_level0_row1" class="row_heading level0 row1" >AMR</th>
#       <td id="T_02e05_row1_col0" class="data row1 col0" >0.297200</td>
#       <td id="T_02e05_row1_col1" class="data row1 col1" >0.272800</td>
#       <td id="T_02e05_row1_col2" class="data row1 col2" >0.172100</td>
#       <td id="T_02e05_row1_col3" class="data row1 col3" >0.204100</td>
#     </tr>
#     <tr>
#       <th id="T_02e05_level0_row2" class="row_heading level0 row2" >EMR</th>
#       <td id="T_02e05_row2_col0" class="data row2 col0" >0.303800</td>
#       <td id="T_02e05_row2_col1" class="data row2 col1" >0.523100</td>
#       <td id="T_02e05_row2_col2" class="data row2 col2" >0.204300</td>
#       <td id="T_02e05_row2_col3" class="data row2 col3" >0.216700</td>
#     </tr>
#     <tr>
#       <th id="T_02e05_level0_row3" class="row_heading level0 row3" >EUR</th>
#       <td id="T_02e05_row3_col0" class="data row3 col0" >0.172100</td>
#       <td id="T_02e05_row3_col1" class="data row3 col1" >0.391900</td>
#       <td id="T_02e05_row3_col2" class="data row3 col2" >0.163400</td>
#       <td id="T_02e05_row3_col3" class="data row3 col3" >0.091000</td>
#     </tr>
#     <tr>
#       <th id="T_02e05_level0_row4" class="row_heading level0 row4" >SEAR</th>
#       <td id="T_02e05_row4_col0" class="data row4 col0" >0.258100</td>
#       <td id="T_02e05_row4_col1" class="data row4 col1" >0.197800</td>
#       <td id="T_02e05_row4_col2" class="data row4 col2" >0.110100</td>
#       <td id="T_02e05_row4_col3" class="data row4 col3" >0.196000</td>
#     </tr>
#     <tr>
#       <th id="T_02e05_level0_row5" class="row_heading level0 row5" >WPR</th>
#       <td id="T_02e05_row5_col0" class="data row5 col0" >0.305300</td>
#       <td id="T_02e05_row5_col1" class="data row5 col1" >0.428500</td>
#       <td id="T_02e05_row5_col2" class="data row5 col2" >0.182700</td>
#       <td id="T_02e05_row5_col3" class="data row5 col3" >0.159900</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Plot Results to compare

# %%
ct = 'WPR'
loc = f"valuations/vimc/"
fw = 'frameworks/hbv_v14_gamma_mav.xlsx'
F = at.ProjectFramework(fw)
D = at.ProjectData.from_spreadsheet(f"applications/region_{ct.lower()}/{ct}_db_mav.xlsx", framework=F)
P= at.Project(framework=F, databook=D, sim_dt=0.25, sim_start=1990, sim_end=2099, do_run=False)
cal = P.make_parset()
cal.load_calibration(f"applications/region_{ct.lower()}/{ct}_calib.xlsx")
res = P.run_sim(parset=cal, result_name = f'{ct} calibration')

d=at.PlotData([res], outputs=['chb_pop', 'cl_acu', 'cl_cir', 'cl_hcc'])
at.plot_series(d, data=P.data, axis="pops")
# Out:
# Elapsed time for running "default": 2.04s
# [<Figure size 432x288 with 1 Axes>,
#  <Figure size 432x288 with 1 Axes>,
#  <Figure size 432x288 with 1 Axes>,
#  <Figure size 432x288 with 1 Axes>]

# %%
import os
wd= 'C:/Users/Phil/Documents/GitHub/hbv-globalinvcase'#set own working directory
os.chdir(wd)

import atomica as at
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import hbv_functions as hbv

# %%
# %matplotlib inline

# %%
regions = ['AFR', 'AMR', 'EMR', 'EUR', 'SEAR', 'WPR']
edf = hbv.error_table(regions)
# Out:
# Current region: AFR
# Elapsed time for running "default": 2.07s
# Current region: AMR
# Elapsed time for running "default": 2.01s
# Current region: EMR
# Elapsed time for running "default": 2.02s
# Current region: EUR
# Elapsed time for running "default": 2.03s
# Current region: SEAR
# Elapsed time for running "default": 2.03s
# Current region: WPR
# Elapsed time for running "default": 2.04s

# %%
edf
# Out:
#       chb_pop  cl_acu  cl_cir  cl_hcc
# AFR    0.2575  0.1460  0.1160  0.6833
# AMR    0.3072  0.1561  0.1566  0.5467
# EMR    0.2398  0.0646  0.2704  0.8895
# EUR    0.1762  0.2420  0.3084  1.1508
# SEAR   0.2774  0.2008  0.1894  0.5262
# WPR    0.3377  0.3573  0.4323  0.4675

# %%
hbv.determine_cal_quality(edf)
# Out:
# <style type="text/css">
# #T_cae31_row0_col0, #T_cae31_row0_col1, #T_cae31_row0_col2, #T_cae31_row1_col0, #T_cae31_row1_col1, #T_cae31_row1_col2, #T_cae31_row2_col0, #T_cae31_row2_col1, #T_cae31_row2_col2, #T_cae31_row3_col0, #T_cae31_row3_col1, #T_cae31_row3_col2, #T_cae31_row4_col0, #T_cae31_row4_col1, #T_cae31_row4_col2, #T_cae31_row5_col0, #T_cae31_row5_col1 {
#   color: black;
#   background-color: mediumseagreen;
# }
# #T_cae31_row0_col3, #T_cae31_row2_col3 {
#   color: white;
#   background-color: red;
# }
# #T_cae31_row1_col3, #T_cae31_row4_col3, #T_cae31_row5_col2, #T_cae31_row5_col3 {
#   color: black;
#   background-color: gold;
# }
# #T_cae31_row3_col3 {
#   color: white;
#   background-color: black;
# }
# </style>
# <table id="T_cae31_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >chb_pop</th>
#       <th class="col_heading level0 col1" >cl_acu</th>
#       <th class="col_heading level0 col2" >cl_cir</th>
#       <th class="col_heading level0 col3" >cl_hcc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cae31_level0_row0" class="row_heading level0 row0" >AFR</th>
#       <td id="T_cae31_row0_col0" class="data row0 col0" >0.257500</td>
#       <td id="T_cae31_row0_col1" class="data row0 col1" >0.146000</td>
#       <td id="T_cae31_row0_col2" class="data row0 col2" >0.116000</td>
#       <td id="T_cae31_row0_col3" class="data row0 col3" >0.683300</td>
#     </tr>
#     <tr>
#       <th id="T_cae31_level0_row1" class="row_heading level0 row1" >AMR</th>
#       <td id="T_cae31_row1_col0" class="data row1 col0" >0.307200</td>
#       <td id="T_cae31_row1_col1" class="data row1 col1" >0.156100</td>
#       <td id="T_cae31_row1_col2" class="data row1 col2" >0.156600</td>
#       <td id="T_cae31_row1_col3" class="data row1 col3" >0.546700</td>
#     </tr>
#     <tr>
#       <th id="T_cae31_level0_row2" class="row_heading level0 row2" >EMR</th>
#       <td id="T_cae31_row2_col0" class="data row2 col0" >0.239800</td>
#       <td id="T_cae31_row2_col1" class="data row2 col1" >0.064600</td>
#       <td id="T_cae31_row2_col2" class="data row2 col2" >0.270400</td>
#       <td id="T_cae31_row2_col3" class="data row2 col3" >0.889500</td>
#     </tr>
#     <tr>
#       <th id="T_cae31_level0_row3" class="row_heading level0 row3" >EUR</th>
#       <td id="T_cae31_row3_col0" class="data row3 col0" >0.176200</td>
#       <td id="T_cae31_row3_col1" class="data row3 col1" >0.242000</td>
#       <td id="T_cae31_row3_col2" class="data row3 col2" >0.308400</td>
#       <td id="T_cae31_row3_col3" class="data row3 col3" >1.150800</td>
#     </tr>
#     <tr>
#       <th id="T_cae31_level0_row4" class="row_heading level0 row4" >SEAR</th>
#       <td id="T_cae31_row4_col0" class="data row4 col0" >0.277400</td>
#       <td id="T_cae31_row4_col1" class="data row4 col1" >0.200800</td>
#       <td id="T_cae31_row4_col2" class="data row4 col2" >0.189400</td>
#       <td id="T_cae31_row4_col3" class="data row4 col3" >0.526200</td>
#     </tr>
#     <tr>
#       <th id="T_cae31_level0_row5" class="row_heading level0 row5" >WPR</th>
#       <td id="T_cae31_row5_col0" class="data row5 col0" >0.337700</td>
#       <td id="T_cae31_row5_col1" class="data row5 col1" >0.357300</td>
#       <td id="T_cae31_row5_col2" class="data row5 col2" >0.432300</td>
#       <td id="T_cae31_row5_col3" class="data row5 col3" >0.467500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# These autocalibrations need to do a better job with hcc

# %% [markdown]
# ### Plot Results to compare

# %%
ct = 'WPR'
loc = f"valuations/vimc/"
fw = 'frameworks/hbv_v14_gamma_mav.xlsx'
F = at.ProjectFramework(fw)
D = at.ProjectData.from_spreadsheet(f"applications/region_{ct.lower()}/{ct}_db_mav.xlsx", framework=F)
P= at.Project(framework=F, databook=D, sim_dt=0.25, sim_start=1990, sim_end=2099, do_run=False)
cal = P.make_parset()
cal.load_calibration(f"applications/region_{ct.lower()}/{ct}_calib.xlsx")
res = P.run_sim(parset=cal, result_name = f'{ct} calibration')

d=at.PlotData([res], outputs=['chb_pop', 'cl_acu', 'cl_cir', 'cl_hcc'])
at.plot_series(d, data=P.data, axis="pops")
# Out:
# Elapsed time for running "default": 2.04s
# [<Figure size 432x288 with 1 Axes>,
#  <Figure size 432x288 with 1 Axes>,
#  <Figure size 432x288 with 1 Axes>,
#  <Figure size 432x288 with 1 Axes>]

# %%
regions = ['AFR', 'AMR', 'EMR', 'EUR', 'SEAR', 'WPR']
edf = hbv.error_table(regions)
# Out:
# Current region: AFR
# Elapsed time for running "default": 2.02s
# Current region: AMR
# Elapsed time for running "default": 2.10s
# Current region: EMR
# Elapsed time for running "default": 2.09s
# Current region: EUR
# Elapsed time for running "default": 2.08s
# Current region: SEAR
# Elapsed time for running "default": 2.12s
# Current region: WPR
# Elapsed time for running "default": 2.08s

# %%
edf
# Out:
#       chb_pop  cl_acu  cl_cir  cl_hcc
# AFR    0.2775  0.1165  0.1263  0.2608
# AMR    0.2777  0.1831  0.1761  0.8106
# EMR    0.2505  0.0939  0.2606  0.1939
# EUR    0.1661  0.2912  0.3461  0.1246
# SEAR   0.2642  0.2118  0.1701  0.3492
# WPR    0.3317  0.3478  0.2060  0.9160

# %%
hbv.determine_cal_quality(edf)
# Out:
# <style type="text/css">
# #T_1e5ba_row0_col0, #T_1e5ba_row0_col1, #T_1e5ba_row0_col2, #T_1e5ba_row0_col3, #T_1e5ba_row1_col0, #T_1e5ba_row1_col1, #T_1e5ba_row1_col2, #T_1e5ba_row2_col0, #T_1e5ba_row2_col1, #T_1e5ba_row2_col2, #T_1e5ba_row2_col3, #T_1e5ba_row3_col0, #T_1e5ba_row3_col1, #T_1e5ba_row3_col2, #T_1e5ba_row3_col3, #T_1e5ba_row4_col0, #T_1e5ba_row4_col1, #T_1e5ba_row4_col2, #T_1e5ba_row4_col3, #T_1e5ba_row5_col0, #T_1e5ba_row5_col1, #T_1e5ba_row5_col2 {
#   color: black;
#   background-color: mediumseagreen;
# }
# #T_1e5ba_row1_col3, #T_1e5ba_row5_col3 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_1e5ba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >chb_pop</th>
#       <th class="col_heading level0 col1" >cl_acu</th>
#       <th class="col_heading level0 col2" >cl_cir</th>
#       <th class="col_heading level0 col3" >cl_hcc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e5ba_level0_row0" class="row_heading level0 row0" >AFR</th>
#       <td id="T_1e5ba_row0_col0" class="data row0 col0" >0.277500</td>
#       <td id="T_1e5ba_row0_col1" class="data row0 col1" >0.116500</td>
#       <td id="T_1e5ba_row0_col2" class="data row0 col2" >0.126300</td>
#       <td id="T_1e5ba_row0_col3" class="data row0 col3" >0.260800</td>
#     </tr>
#     <tr>
#       <th id="T_1e5ba_level0_row1" class="row_heading level0 row1" >AMR</th>
#       <td id="T_1e5ba_row1_col0" class="data row1 col0" >0.277700</td>
#       <td id="T_1e5ba_row1_col1" class="data row1 col1" >0.183100</td>
#       <td id="T_1e5ba_row1_col2" class="data row1 col2" >0.176100</td>
#       <td id="T_1e5ba_row1_col3" class="data row1 col3" >0.810600</td>
#     </tr>
#     <tr>
#       <th id="T_1e5ba_level0_row2" class="row_heading level0 row2" >EMR</th>
#       <td id="T_1e5ba_row2_col0" class="data row2 col0" >0.250500</td>
#       <td id="T_1e5ba_row2_col1" class="data row2 col1" >0.093900</td>
#       <td id="T_1e5ba_row2_col2" class="data row2 col2" >0.260600</td>
#       <td id="T_1e5ba_row2_col3" class="data row2 col3" >0.193900</td>
#     </tr>
#     <tr>
#       <th id="T_1e5ba_level0_row3" class="row_heading level0 row3" >EUR</th>
#       <td id="T_1e5ba_row3_col0" class="data row3 col0" >0.166100</td>
#       <td id="T_1e5ba_row3_col1" class="data row3 col1" >0.291200</td>
#       <td id="T_1e5ba_row3_col2" class="data row3 col2" >0.346100</td>
#       <td id="T_1e5ba_row3_col3" class="data row3 col3" >0.124600</td>
#     </tr>
#     <tr>
#       <th id="T_1e5ba_level0_row4" class="row_heading level0 row4" >SEAR</th>
#       <td id="T_1e5ba_row4_col0" class="data row4 col0" >0.264200</td>
#       <td id="T_1e5ba_row4_col1" class="data row4 col1" >0.211800</td>
#       <td id="T_1e5ba_row4_col2" class="data row4 col2" >0.170100</td>
#       <td id="T_1e5ba_row4_col3" class="data row4 col3" >0.349200</td>
#     </tr>
#     <tr>
#       <th id="T_1e5ba_level0_row5" class="row_heading level0 row5" >WPR</th>
#       <td id="T_1e5ba_row5_col0" class="data row5 col0" >0.331700</td>
#       <td id="T_1e5ba_row5_col1" class="data row5 col1" >0.347800</td>
#       <td id="T_1e5ba_row5_col2" class="data row5 col2" >0.206000</td>
#       <td id="T_1e5ba_row5_col3" class="data row5 col3" >0.916000</td>
#     </tr>
#   </tbody>
# </table>

# %%
regions = ['AFR', 'AMR', 'EMR', 'EUR', 'SEAR', 'WPR']
edf = hbv.error_table(regions)
# Out:
# Current region: AFR
# Elapsed time for running "default": 2.04s
# Current region: AMR
# Elapsed time for running "default": 2.01s
# Current region: EMR
# Elapsed time for running "default": 2.03s
# Current region: EUR
# Elapsed time for running "default": 2.00s
# Current region: SEAR
# Elapsed time for running "default": 2.05s
# Current region: WPR
# Elapsed time for running "default": 2.02s

# %%
edf
# Out:
#       chb_pop  cl_acu  cl_cir  cl_hcc
# AFR    0.2775  0.1165  0.1263  0.2608
# AMR    0.3327  0.1812  0.1710  0.2207
# EMR    0.2505  0.0939  0.2606  0.1939
# EUR    0.1661  0.2912  0.3461  0.1246
# SEAR   0.2642  0.2118  0.1701  0.3492
# WPR    0.3376  0.3925  0.2479  0.2237

# %%
hbv.determine_cal_quality(edf)
# Out:
# <style type="text/css">
# #T_63602_row0_col0, #T_63602_row0_col1, #T_63602_row0_col2, #T_63602_row0_col3, #T_63602_row1_col0, #T_63602_row1_col1, #T_63602_row1_col2, #T_63602_row1_col3, #T_63602_row2_col0, #T_63602_row2_col1, #T_63602_row2_col2, #T_63602_row2_col3, #T_63602_row3_col0, #T_63602_row3_col1, #T_63602_row3_col2, #T_63602_row3_col3, #T_63602_row4_col0, #T_63602_row4_col1, #T_63602_row4_col2, #T_63602_row4_col3, #T_63602_row5_col0, #T_63602_row5_col1, #T_63602_row5_col2, #T_63602_row5_col3 {
#   color: black;
#   background-color: mediumseagreen;
# }
# </style>
# <table id="T_63602_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >chb_pop</th>
#       <th class="col_heading level0 col1" >cl_acu</th>
#       <th class="col_heading level0 col2" >cl_cir</th>
#       <th class="col_heading level0 col3" >cl_hcc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63602_level0_row0" class="row_heading level0 row0" >AFR</th>
#       <td id="T_63602_row0_col0" class="data row0 col0" >0.277500</td>
#       <td id="T_63602_row0_col1" class="data row0 col1" >0.116500</td>
#       <td id="T_63602_row0_col2" class="data row0 col2" >0.126300</td>
#       <td id="T_63602_row0_col3" class="data row0 col3" >0.260800</td>
#     </tr>
#     <tr>
#       <th id="T_63602_level0_row1" class="row_heading level0 row1" >AMR</th>
#       <td id="T_63602_row1_col0" class="data row1 col0" >0.332700</td>
#       <td id="T_63602_row1_col1" class="data row1 col1" >0.181200</td>
#       <td id="T_63602_row1_col2" class="data row1 col2" >0.171000</td>
#       <td id="T_63602_row1_col3" class="data row1 col3" >0.220700</td>
#     </tr>
#     <tr>
#       <th id="T_63602_level0_row2" class="row_heading level0 row2" >EMR</th>
#       <td id="T_63602_row2_col0" class="data row2 col0" >0.250500</td>
#       <td id="T_63602_row2_col1" class="data row2 col1" >0.093900</td>
#       <td id="T_63602_row2_col2" class="data row2 col2" >0.260600</td>
#       <td id="T_63602_row2_col3" class="data row2 col3" >0.193900</td>
#     </tr>
#     <tr>
#       <th id="T_63602_level0_row3" class="row_heading level0 row3" >EUR</th>
#       <td id="T_63602_row3_col0" class="data row3 col0" >0.166100</td>
#       <td id="T_63602_row3_col1" class="data row3 col1" >0.291200</td>
#       <td id="T_63602_row3_col2" class="data row3 col2" >0.346100</td>
#       <td id="T_63602_row3_col3" class="data row3 col3" >0.124600</td>
#     </tr>
#     <tr>
#       <th id="T_63602_level0_row4" class="row_heading level0 row4" >SEAR</th>
#       <td id="T_63602_row4_col0" class="data row4 col0" >0.264200</td>
#       <td id="T_63602_row4_col1" class="data row4 col1" >0.211800</td>
#       <td id="T_63602_row4_col2" class="data row4 col2" >0.170100</td>
#       <td id="T_63602_row4_col3" class="data row4 col3" >0.349200</td>
#     </tr>
#     <tr>
#       <th id="T_63602_level0_row5" class="row_heading level0 row5" >WPR</th>
#       <td id="T_63602_row5_col0" class="data row5 col0" >0.337600</td>
#       <td id="T_63602_row5_col1" class="data row5 col1" >0.392500</td>
#       <td id="T_63602_row5_col2" class="data row5 col2" >0.247900</td>
#       <td id="T_63602_row5_col3" class="data row5 col3" >0.223700</td>
#     </tr>
#   </tbody>
# </table>
